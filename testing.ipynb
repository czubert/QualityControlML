# %%
import pandas
import numpy 
import pickle
import matplotlib.pyplot as plt

# %%
with open('./DataFrame/df.pkl', 'rb') as file:

    df = pickle.load(file)

# %%
df
# Out:
# Raman Shift           254      257      259      262      264      266  \
# 2023_07_13 sp_1   13540.0  13474.0  13379.0  13152.0  13290.0  13241.0
# 2023_07_13 sp_10  19559.0  19559.0  19244.0  19013.0  19124.0  18814.0
# 2023_07_13 sp_11  13546.0  13749.0  13547.0  13361.0  13530.0  13159.0
# 2023_07_13 sp_12  15240.0  15111.0  14786.0  14643.0  14942.0  14812.0
# 2023_07_13 sp_13  14081.0  14016.0  13890.0  13565.0  13997.0  13560.0
# ...                   ...      ...      ...      ...      ...      ...
# 2023_07_19 sp_85  64424.0  64415.0  64593.0  64512.0  64491.0  64493.0
# 2023_07_19 sp_86  64424.0  64415.0  64593.0  64512.0  64491.0  64493.0
# 2023_07_19 sp_87  64424.0  64415.0  64593.0  64512.0  64491.0  64493.0
# 2023_07_19 sp_88  64424.0  64415.0  64593.0  64512.0  64491.0  64493.0
# 2023_07_19 sp_9   39400.0  39797.0  39493.0  38768.0  38826.0  38282.0
#
# Raman Shift           269      271      273      276  ...    2483    2484  \
# ...
